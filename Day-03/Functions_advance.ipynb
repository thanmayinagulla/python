# %%
#Find the Largest Number
def largest(a, b, c):
    if a > b and a > c:
        print("a is the largest number")
    elif b > a and b > c:
        print("b is the largest number")
    else:
        print("c is the largest number")


a = int(input("Enter the value of a: "))
b = int(input("Enter the value of b: "))
c = int(input("Enter the value of c: "))

largest(a, b, c)
# Out:
# Enter the value of a: 13
# Enter the value of b: 15
# Enter the value of c: 79
# c is the largest number

# %%
#Check Leap Year
def leap():
  year = int(input("Enter a year: "))
  if (year % 4 == 0 and year % 100 != 0) or (year % 400 == 0):
      print(year, "is a leap year")
  else:
      print(year, "is not a leap year")


leap()
# Out:
# Enter a year: 2006
# 2006 is not a leap year

# %%
#count vowels
def count_vowels():
  string= input("enter the sring:")
  count=0
  for i in string:
    if i in "aeiouAEIOU":
      count=count+1
  print("number of vowels in the string:",count)
count_vowels()
count_vowels()
# Out:
# enter the sring:thanu
# number of vowels in the string: 2
# enter the sring:thanu
# number of vowels in the string: 2

# %%
#Reverse a String.
def reverse_string():
  user_string = input("Enter the string:")
  reversed_str = user_string[::-1]
  print("Reversed string:", reversed_str)

reverse_string()
# Out:
# Enter the string:thanu
# Reversed string: unaht

# %%
#count Uppercase and Lowercase Letters
def count_upper_lower():
  user_string = input("Enter the string:")
  upper_count = 0
  lower_count = 0
  for char in user_string:
    if char.isupper():
      upper_count += 1
    elif char.islower():
      lower_count += 1
  print("Number of uppercase letters:", upper_count)
  print("Number of lowercase letters:", lower_count)

count_upper_lower()
# Out:
# Enter the string:Thanmayi Nagulla
# Number of uppercase letters: 2
# Number of lowercase letters: 13
