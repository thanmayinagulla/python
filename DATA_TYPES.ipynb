# %%
#Create a variable name and store your name in it. Print the variable.
Name="Thanuu"
print("Name:",Name)
# Out:
# Name: Thanuu

# %%
#Create a variable age with your age. Print its data type.
Age=19
print(type(Age))
# Out:
# <class 'int'>

# %%
#Create a float variable called cgpa and assign any decimal value.
Cgpa= 9.4
print("Cgpa:",Cgpa)
# Out:
# Cgpa: 9.4

# %%
#Create a boolean variable named is_student and assign an appropriate value.
Is_student=True
print(Is_student)
# Out:
# True

# %%
#Create two integer variables a and b. Print their sum.
a=10
b=27
print("a+b=",a+b)
# Out:
# a+b= 37

# %%
"""create two strings:

"Hello"
"Python"

Print them together """

a="Hello"
b="python"
print(a+b)
# Out:
# Hellopython

# %%
#Store the number 50 in a variable. Convert it to a float and print it.
a=50
print(float(a))
# Out:
# 50.0

# %%
#Store the decimal number 25.8. Convert it to an integer and print it.
a=25.6
print(int(a))
# Out:
# 25

# %%
#Store the integer 100. Convert it to a string and print its data type

a=100
a = str(a) # Convert the integer to a string
print(a) # Print the string
print(type(a)) # Print the data type of the string
# Out:
# 100
# <class 'str'>

# %%
#Take your name as input and print
Name= input("enter your Name")
print(Name)
# Out:
# enter your Namethanmayi nagulla
# thanmayi nagulla
